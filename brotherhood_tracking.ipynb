# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/brotherhood
# Out:
# /content/drive/MyDrive/brotherhood

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch.git

# %%
# %cd Yolov5_DeepSort_Pytorch
# Out:
# /content/drive/MyDrive/brotherhood/Yolov5_DeepSort_Pytorch

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ***Tracking process***

# %%
# !python track.py --source /content/drive/MyDrive/brotherhood/Yolov5_DeepSort_Pytorch/yolov5/runs/video4.mp4 --yolo-weights /content/drive/MyDrive/brotherhood/yolov5_custom_trained_best.pt --img 416  --strong-sort-weights osnet_x0_25_msmt17.pt  --save-vid
# Out:
# strong_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# track: yolo_weights=['/content/drive/MyDrive/brotherhood/yolov5_custom_trained_best.pt'], strong_sort_weights=osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=/content/drive/MyDrive/brotherhood/Yolov5_DeepSort_Pytorch/yolov5/runs/video4.mp4, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python track.py --source /content/drive/MyDrive/brotherhood/Yolov5_DeepSort_Pytorch/yolov5/runs/video3.mp4 --yolo-weights /content/drive/MyDrive/brotherhood/yolov5_custom_trained_best.pt --img 416  --strong-sort-weights osnet_x0_25_msmt17.pt  --save-vid
# Out:
# strong_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# track: yolo_weights=['/content/drive/MyDrive/brotherhood/yolov5_custom_trained_best.pt'], strong_sort_weights=osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=/content/drive/MyDrive/brotherhood/Yolov5_DeepSort_Pytorch/yolov5/runs/video3.mp4, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
