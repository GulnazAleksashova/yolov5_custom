# %%
# !pip install tensorflow==2.3.1

# %%
# !pip install tensorboard==2.4.1

# %%
import torch
from IPython.display import Image
import os
from random import choice
import shutil
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/brotherhood
# Out:
# /content/drive/MyDrive/brotherhood

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/brotherhood/yolov5

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ***Inference of the model***

# %%
# !python detect.py --source runs/1.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/1.jpg: 288x640 1 frodo, 1 samwise, 1 pippin, 1 merry, Done. (0.015s)
# Speed: 0.6ms pre-process, 14.9ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp64

# %%
Image(filename='runs/detect/exp64/1.jpg', width=416)

# %%
# !python detect.py --source runs/4.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/4.jpg: 288x640 1 frodo, 1 samwise, 1 pippin, 1 merry, 1 gandalf, 1 aragorn, 1 legolas, 1 gimli, 1 boromir, Done. (0.016s)
# Speed: 0.6ms pre-process, 15.9ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp65

# %%
Image(filename='runs/detect/exp65/4.jpg', width=416)

# %%
# !python detect.py --source runs/5.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/5.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/5.jpg: 288x640 1 gandalf, 1 aragorn, Done. (0.014s)
# Speed: 0.8ms pre-process, 14.3ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp66

# %%
Image(filename='runs/detect/exp66/5.jpg', width=416)

# %%
# !python detect.py --source runs/9.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/9.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/9.jpg: 288x640 1 gandalf, 1 legolas, Done. (0.195s)
# Speed: 2.0ms pre-process, 195.1ms inference, 9.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp67

# %%
Image(filename='runs/detect/exp67/9.jpg', width=416)

# %%
# !python detect.py --source runs/Wood3.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/Wood3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/Wood3.jpg: 640x480 Done. (0.298s)
# Speed: 2.7ms pre-process, 298.2ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp68

# %%
Image(filename='runs/detect/exp68/Wood3.jpg', width=416)
# c реальным актером не работает

# %%
# !python detect.py --source runs/frodo3_9.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_9.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_9.jpg: 448x640 Done. (0.268s)
# Speed: 2.8ms pre-process, 268.2ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp72

# %%
Image(filename='runs/detect/exp72/frodo3_9.jpg', width=416)

# %%
# !python detect.py --source runs/video1.avi --weights runs/train/exp61/weights/best.pt

# %%
# !python detect.py --source runs/video2.avi --weights runs/train/exp61/weights/best.pt

# %%
# !python detect.py --source runs/video1.avi --weights runs/train/exp58/weights/best.pt

# %%
# !python detect.py --source runs/brothers_1.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/brothers_1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/brothers_1.jpg: 384x640 1 frodo, 1 samwise, 1 gandalf, 1 boromir, Done. (0.241s)
# Speed: 2.6ms pre-process, 241.3ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp76

# %%
Image(filename='runs/detect/exp76/brothers_1.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_3.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_3.jpg: 384x640 Done. (0.242s)
# Speed: 2.5ms pre-process, 242.4ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp78

# %%
Image(filename='runs/detect/exp78/frodo3_3.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_11.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_11.jpg: 640x448 1 aragorn, Done. (0.260s)
# Speed: 2.8ms pre-process, 259.7ms inference, 9.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp79

# %%
Image(filename='runs/detect/exp79/frodo3_11.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_6.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_6.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_6.jpg: 480x640 Done. (0.290s)
# Speed: 2.6ms pre-process, 290.0ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp80

# %%
Image(filename='runs/detect/exp80/frodo3_6.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_4.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_4.jpg: 288x640 1 frodo, 1 pippin, Done. (0.164s)
# Speed: 2.1ms pre-process, 164.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp81

# %%
Image(filename='runs/detect/exp81/frodo3_4.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_5.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_5.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_5.jpg: 384x640 1 legolas, 1 gimli, Done. (0.243s)
# Speed: 2.6ms pre-process, 243.3ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp82

# %%
Image(filename='runs/detect/exp82/frodo3_5.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_7.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_7.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_7.jpg: 448x640 Done. (0.246s)
# Speed: 2.8ms pre-process, 245.7ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp83

# %%
Image(filename='runs/detect/exp83/frodo3_7.jpg', width=416)

# %%
# !python detect.py --source runs/frodo3_10.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo3_10.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo3_10.jpg: 448x640 Done. (0.252s)
# Speed: 2.9ms pre-process, 252.5ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp84

# %%
Image(filename='runs/detect/exp84/frodo3_10.jpg', width=416)

# %%
# !python detect.py --source runs/Wood2.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/Wood2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/Wood2.jpg: 640x544 Done. (0.296s)
# Speed: 4.4ms pre-process, 296.1ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp85

# %%
Image(filename='runs/detect/exp85/Wood2.jpg', width=416)

# %%
# !python detect.py --source runs/wood7.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/wood7.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/wood7.jpg: 384x640 2 frodos, Done. (0.210s)
# Speed: 2.2ms pre-process, 210.1ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp87

# %%
Image(filename='runs/detect/exp87/wood7.jpg', width=416)

# %%
# !python detect.py --source runs/frodo2_0.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/frodo2_0.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/frodo2_0.jpg: 640x640 Done. (0.347s)
# Speed: 4.1ms pre-process, 347.0ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp88

# %%
Image(filename='runs/detect/exp88/frodo2_0.jpg', width=416)

# %%
# !python detect.py --source runs/video3.mp4 --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/video3.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/535) /content/drive/MyDrive/brotherhood/yolov5/runs/video3.mp4: 288x640 1 frodo, 1 samwise, Done. (0.169s)
# video 1/1 (2/535) /content/drive/MyDrive/brotherhood/yolov5/runs/video3.mp4: 288x640 1 frodo, 1 samwise, Done. (0.154s)
# video 1/1 (3/535) /content/drive/MyDrive/brotherhood/yolov5/runs/video3.mp4: 288x640 1 frodo, 1 samwise, Done. (0.156s)
# ...

# %%
# !python detect.py --source runs/video4.mp4 --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/video4.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/418) /content/drive/MyDrive/brotherhood/yolov5/runs/video4.mp4: 384x640 Done. (0.215s)
# video 1/1 (2/418) /content/drive/MyDrive/brotherhood/yolov5/runs/video4.mp4: 384x640 Done. (0.212s)
# video 1/1 (3/418) /content/drive/MyDrive/brotherhood/yolov5/runs/video4.mp4: 384x640 Done. (0.217s)
# ...

# %%
# !python detect.py --source runs/3.jpg --weights runs/train/exp61/weights/best.pt
# Out:
# detect: weights=['runs/train/exp61/weights/best.pt'], source=runs/3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/brotherhood/yolov5/runs/3.jpg: 288x640 1 frodo, 1 legolas, 1 gimli, Done. (0.197s)
# Speed: 2.6ms pre-process, 197.4ms inference, 13.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp92

# %%
Image(filename='runs/detect/exp92/3.jpg', width=416)
